# %% [markdown]
# derive class replace same method from base class

# %%
class Animal:

    def sound(self):
        print("making soung")

# %%
# derive class
class Dog(Animal):

    def sound(base):
        
        # running method of animal base class
        super().sound()

        print("dog barks")

# %%
obj = Dog()

# %%
obj.sound()
# Out:
# making soung
# dog barks
