# %% [markdown]
# Creating a NumPy Array:
# NumPy arrays are a powerful way to store and process large datasets. In this section, you will learn to create arrays.
#
# Task 2:
#
# Create a 1D NumPy array from a Python list of numbers: [1, 2, 3, 4, 5].
# Create a 2D NumPy array of shape (3x3) using the numbers from 1 to 9.
# Generate an array of 10 evenly spaced values between 0 and 5.

# %% [markdown]
# 1D

# %%
import numpy as np

# %%
list_1 = np.array([1,2,3,4,5])

# %%
list_1
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# 2D

# %%
two_d = np.random.randint(1,9 ,size = (3, 3))

# %%
two_d
# Out:
# array([[1, 8, 8],
#        [4, 6, 5],
#        [5, 4, 4]])

# %%
evenly_spaced = np.linspace(1, 5, num = 10, axis = 0) #axis define row wise or column wise work, 1 = row, 0 = column

# %%
print(np.round(evenly_spaced,3))
# Out:
# [1.    1.444 1.889 2.333 2.778 3.222 3.667 4.111 4.556 5.   ]

# %% [markdown]
# Access the element in the second row, third column of the 2D array you created above.

# %%
two_d
# Out:
# array([[1, 8, 8],
#        [4, 6, 5],
#        [5, 4, 4]])

# %%
two_d[1:2, 2:]
# Out:
# array([[5]])

# %% [markdown]
# Slice the first two rows and the first two columns from the same array.

# %%
two_d[:2, :2]
# Out:
# array([[1, 8],
#        [4, 6]])

# %% [markdown]
# Modify the value in the last row and first column to 100.

# %%
two_d[-1, 0] = 100

# %%
two_d
# Out:
# array([[  1,   8,   8],
#        [  4,   6,   5],
#        [100,   4,   4]])

# %% [markdown]
# #  Properties and Methods of NumPy Arrays

# %% [markdown]
# Find the shape, size, and data type of the 2D array.

# %%
two_d.shape
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# (3, 3)

# %%
two_d.size
# Out:
# 9

# %%
type(two_d)
# Out:
# numpy.ndarray

# %% [markdown]
# Change the 1D array into a 2D array of shape (5,1).

# %%
list_1
# Out:
# [1, 2, 3, 4, 5]

# %%
array_1D_2D = np.reshape(list_1,shape = (5,1 ))

# %%
array_1D_2D
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %% [markdown]
# Flatten a multi-dimensional array back into a 1D array.

# %%
array_1D_2D.flatten()
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# # Operations on NumPy Arrays

# %% [markdown]
# Add 5 to every element in the 1D array.

# %%
list_1
# Out:
# array([1, 2, 3, 4, 5])

# %%
addition = np.add(list_1, 5)

# %%
addition
# Out:
# array([ 6,  7,  8,  9, 10])

# %% [markdown]
# Multiply the 2D array by 3.

# %%
two_d
# Out:
# array([[  1,   8,   8],
#        [  4,   6,   5],
#        [100,   4,   4]])

# %%
multiply = np.multiply(two_d, 3)

# %%
multiply
# Out:
# array([[  3,  24,  24],
#        [ 12,  18,  15],
#        [300,  12,  12]])

# %%
A = np.array([[1, 2], [3, 4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B = np.array([[5, 6], [7, 8]])

# %%
B
# Out:
# array([[5, 6],
#        [7, 8]])

# %% [markdown]
# Perform matrix multiplication between the following two arrays:

# %%
result = np.dot(A, B)

# %%
result
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# # Understanding Broadcasting

# %% [markdown]
# Create a 3x3 matrix of ones and a 1D array of length 3.

# %%
three_three = matrix = np.ones((3, 3))

# %%
three_three
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
arrayy= np.array([1, 2, 3])

# %%
arrayy
# Out:
# array([1, 2, 3])

# %% [markdown]
# Add the 1D array to each row of the matrix using broadcasting.
