# %%
print(4,5,sep="+",end="\n") #\n normally default print for end and seperator is space.
print("hello world")
# Out:
# 4+5
# hello world

# %%
print("hello", "world",sep="-")
# Out:
# hello-world

# %%
# type(), input()
type(4!=2)
# Out:
# bool

# %%
# isinstance = object ko instance
isinstance(3,int)
# Out:
# True

# %%
isinstance("hari",str)
# Out:
# True

# %%
# length=len() used for str, list. tuple or dict
len("False")
# Out:
# 5

# %%
## all and any
list_bool=[True,False, True,False,False,True]

any(list_bool)
all(list_bool)
# Out:
# False

# %%
# open
file=open("space.txt",mode="r")
file
# to read
print(file.read())
# Out:
# hello i am from space.

# %%
# file to close becassue background ma memory khaira huncha
file.close()

# %%
file=open("log.txt",mode='r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 file=open("log.txt",mode='r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'log.txt'

# %%
# when i use w mode for not existing file it creates
file=open("log.txt",mode='w')
file.write("this is my first log.\n")
file.write("this is my second log")
file.close() #if not closed, it wont save file

# %%
# to avoid close we use with called built in context manager for file handling
with open("space.txt",mode='r+')as file:
    print(file.read())
    file.write("\n hello all")
print("closed")
# Out:
# hello i am from space.
# closed

# %%
print(dir(2.0))
# Out:
# ['__abs__', '__add__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getformat__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__int__', '__le__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__pos__', '__pow__', '__radd__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', 'as_integer_ratio', 'conjugate', 'fromhex', 'hex', 'imag', 'is_integer', 'real']

# %%
# enumerate, use to iterate over a requence and return sequence of tuples
lst=["a","b","c"] 
res=enumerate(lst)
list(res)
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
for i,name in enumerate(lst,start=1):
    print(f"{name} - Roll No {i}")
# Out:
# a - Roll No 1
# b - Roll No 2
# c - Roll No 3

# %%
# zip() combine two or more iterables
names_=["hari","shyam"]
marks=[89,54]
list(zip(names_,marks))
# Out:
# [('hari', 89), ('shyam', 54)]

# %%
# eval(), arbiratory object lai compileable ma convert
script=""" 

"""
