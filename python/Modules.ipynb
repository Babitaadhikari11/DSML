# %%
# OS Module
import os
# get current working directory
os.getcwd()
# make new directory
os.mkdir("test") #makes in the current working directory
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[1], line 6
#       2 import os
#       3 # get current working directory
#       4 os.getcwd()
#       5 # make new directory
# ----> 6 os.mkdir("test") #makes in the current working directory
#
# FileExistsError: [Errno 17] File exists: 'test'

# %%
os.chdir("test")

# %%
os.getcwd()
# Out:
# '/Users/babitaadhikari/DSML/python/test'

# %%
# move one step backward from current directory
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/Users/babitaadhikari/DSML/python'

# %%
# check path
os.path.exists("test")
# Out:
# True

# %% [markdown]
# Python OS Module
# The os module in Python provides a way of interacting with the operating system. It provides a way to access and manipulate files and directories, start and stop processes, get information about the system, and more.
#
# Working with Files and Directories
# Let's explore the os module and its various functions and methods that support working with files and directories.
#
# os.getcwd(): Get the current working directory
# os.mkdir('path'): Create a new directory
# os.chdir('path'): Change the current working directory
# os.listdir('path'): List the contents of a directory
# os.rename('old_name', 'new_name): Rename a file or a directory
# os.remove('file_to_delete'): Remove a file
# os.rmdir('directory_to_delete'): Remove a directory
# os.path.dirname('path'): Returns the name of the directory containing pathname path
# os.path.exists('path'): Checks if the path already exists, if so returns True

# %%
# OS Module
import os

# %%
# make folder with same name even if it exist
os.makedirs("test", exist_ok=True)

# %%
# joining multiple path to make one
os.path.join("test", "file.txt")
# Out:
# 'test'

# %%
# list individual paths
os.listdir()
# Out:
# ['test',
#  'UserDefineFunction.ipynb',
#  'Modules.ipynb',
#  'MagicalMethod.ipynb',
#  'PythonLoop.ipynb',
#  'space.txt',
#  'DataType.ipynb',
#  'log.txt',
#  'Revision.ipynb',
#  '.ipynb_checkpoints',
#  'pythonBuiltInFunction.ipynb',
#  '.git',
#  'intro.py']

# %%
os.listdrives() #for windows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.listdrives()
#
# AttributeError: module 'os' has no attribute 'listdrives'

# %%
# environment variable
os.environ
# Out:
# environ{'COMMAND_MODE': 'unix2003',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_EXE': '/opt/anaconda3/bin/conda',
#         'CONDA_PREFIX': '/opt/anaconda3',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'CONDA_PYTHON_EXE': '/opt/anaconda3/bin/python',
#         'CONDA_SHLVL': '1',
#         'FPATH': '/opt/homebrew/share/zsh/site-functions:/usr/local/share/zsh/site-functions:/usr/share/zsh/site-functions:/usr/share/zsh/5.9/functions',
#         'GSETTINGS_SCHEMA_DIR': '/opt/anaconda3/share/glib-2.0/schemas',
#         'HOME': '/Users/babitaadhikari',
#         'HOMEBREW_CELLAR': '/opt/homebrew/Cellar',
#         'HOMEBREW_PREFIX': '/opt/homebrew',
#         'HOMEBREW_REPOSITORY': '/opt/homebrew',
#         'INFOPATH': '/opt/homebrew/share/info:',
#         'JAVA_HOME': '/Library/Java/JavaVirtualMachines/temurin-8.jdk/Contents/Home',
#         'LANG': 'C.UTF-8',
#         'LOGNAME': 'babitaadhikari',
#         'MallocNanoZone': '0',
#         'OLDPWD': '/',
# ...

# %%
os.environ["SECRETPass"] = "djf234djscsv"

# %%
os.getenv("SECRETPass")
# Out:
# 'djf234djscsv'

# %% [markdown]
# RandomModule

# %%
import random

# %%
# generate random number between [0,1)
random.random()
# Out:
# 0.19194809060456042

# %%
# between two , both inclusive
random.uniform(10,20)
# Out:
# 13.838463813095466

# %%
# for whole number
random.randint(10,20)
# Out:
# 20

# %%
# list of random number , select one random number
random.randrange(2, 10, 2)
# Out:
# 8

# %%
# sequence related functions
cards = ["nine", "ten", "jack", "queen", "king", "ace"]

# %%
random.shuffle(cards)

# %%
cards
# Out:
# ['queen', 'ace', 'jack', 'ten', 'king', 'nine']

# %%
random.choice(cards)
# Out:
# 'queen'

# %%
random.choices(cards, k = 3) #selecting three random cards, with replacement
# Out:
# ['ten', 'nine', 'queen']

# %%
random.sample(cards, counts=[4] * 6, k=3) #withoutreplacement-  no duplicates
# Out:
# ['nine', 'ace', 'jack']

# %%
# distribution and probability density function

# %%
random.normalvariate(mu=5 ,sigma=5.2)
# Out:
# 13.45321615106295

# %%
random.expovariate(3)
# Out:
# 0.42630214254278104

# %%
# randomness-related function
random.seed(456)

# %%
random.random()
# Out:
# 0.7482025358782363

# %%
random.randint(1,100)
# Out:
# 60

# %%
# DateTime

# %%
# datetime module
import datetime

# %%
birth_date = datetime.date(2004, 7, 28)

# %%
birth_date
# Out:
# datetime.date(2004, 7, 28)

# %%
today_date = datetime.date.today()

# %%
today_date
# Out:
# datetime.date(2026, 8, 17)

# %%
age =  today_date - birth_date

# %%
age.days / 365
# Out:
# 22.068493150684933

# %%
datetime.date.fromtimestamp()
